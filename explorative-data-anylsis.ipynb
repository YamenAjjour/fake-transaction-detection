# %%
import seaborn as sns
import pandas as pd


data_file = "data_fakes.csv"

df = pd.read_csv(data_file, sep=",")

# %%
df["Fake"].value_counts()

# size of the data is 11,358
# Fake products is 1217
# Unfake products is 10141
sns.displot(df,x="AveragePrice", hue="Fake")

# %%
sns.displot(df,x="ProductAge", hue="Fake")

# %%
sns.displot(df,x="VNZIP1", hue="Fake")

# %%
df["len-desc"] = df["product_description"].map(lambda x: len(x))

# %%
sns.displot(df,x="len-desc", hue="Fake")

# %%
len(df["ProductName"].unique())
# Out:
# 703

# %%
value_counts = df["ProductName"].value_counts()

# %%
value_counts[:10]
# Out:
# ProductName
# Frigidaire FGGC3047QB Gallery 30-Inch Gas Cooktop, Black                                   350
# Urparcel Pet Puppy Dog Cat Sleeping Bed Cushion Mat Kennel Nest Warm House Green           336
# Humidifier Filter Wick for Lasko Natural Cascade  THF8  THF-8 1128, 1129, 9930 (6-Pack)    244
# Exhaust Filter Set for Sonya and Panda Dryer                                               236
# SPT SD-9252SS Energy Star 18&quot; Built-In Dishwasher, Stainless Steel                    205
# French Bulldog Clean Dirty Dishwasher Magnet No 2                                          191
# Toppik Fiber Hold Spray, 4 oz                                                              183
# GE RPWFE Refrigerator Water Filter                                                         180
# Cosequin Soft Chews Maximum Strength with MSM Plus Omega 3, 120 count                      178
# Outward Hound Tail Teaser Dog Flirt Pole Toy                                               167
# ...
